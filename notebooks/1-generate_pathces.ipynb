# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import tifffile as tiff
from tifffile import imsave

from deepcell.utils.plot_utils import create_rgb_image

import logging

# Configure logging
logging.basicConfig(level=logging.INFO)

# %%
import sys
src_dir = "/workspaces/codex-analysis/0-phenocycler-penntmc-pipeline"
sys.path.append(src_dir)

from aegle.img_preprocessing import extend_image, crop_image_into_patches, visualize_and_save_patch, visualize_patch

# %%
output_dir = "/workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out"
os.makedirs(output_dir, exist_ok=True)

data_dir = "/workspaces/codex-analysis/data"
# file_name = "/data/NW_Ovary_16/Scan1/NW_1_Scan1.qptiff"
file_name = "NW_Ovary_16/Scan1/NW_1_Scan1.qptiff"
file_name = f"{data_dir}/{file_name}"

image_ndarray = tiff.imread(file_name)
image_ndarray = np.expand_dims(image_ndarray, axis=0)
# Step 2: Move the feature channels to the last axis
# Current shape is (1, channels, height, width), we want (1, height, width, channels)
image_ndarray = np.transpose(image_ndarray, (0, 2, 3, 1))
# Prepare image details for user display
tif_image_details = {
    'Data Type': image_ndarray.dtype,
    'Shape': image_ndarray.shape}

tif_image_details
# Out:
# {'Data Type': dtype('uint8'), 'Shape': (1, 50400, 28800, 35)}

# %%
# Read channel list
file_name = "/workspaces/codex-analysis/data/NW_Ovary_16/Scan1/extras/antibodies.tsv"
antibody_df = pd.read_csv(file_name, sep='\t')

nuclear_chanell_name = "DAPI"
wholecell_chanell_name = "CD4"
target_channel_names = [nuclear_chanell_name, wholecell_chanell_name]
# Get the index for the target channels
target_channel_idx = antibody_df[antibody_df['antibody_name'].isin(target_channel_names)].index.tolist()
print(antibody_df['antibody_name'].to_list())
print(target_channel_idx)

# Only keep the first two channels
# channel_numbers = [0, 21]
image_ndarray_target_channel = image_ndarray[:, :, :, target_channel_idx]
print(image_ndarray_target_channel.shape)
# Out:
# ['DAPI', 'CD44', 'CD20', 'CD11c', 'E-cadherin', 'Beta-actin', 'CD56', 'b-Catenin1', 'Pan-Cytokeratin', 'Collagen IV', 'CD8', 'HLA-DR', 'CD3e', 'Podoplanin', 'Caveolin', 'CD45RO', 'CD31', 'Ki67', 'CD34', 'CD45', 'Vimentin', 'CD4', 'DDX4', 'FOXL2', 'CD68', 'CD14', 'SMA', 'IBAL', 'HLA-A', 'CD20', 'EMILIN', 'FN1', 'DCN', 'LUM', 'CDLN']
# [0, 21]
# (1, 50400, 28800, 2)

# %%
# Define patch size and overlap
patch_height, patch_width = 1440, 1920
overlap = 0.1
overlap_height = int(patch_height * overlap)
overlap_width = int(patch_width * overlap)

# Extract image dimensions
_, img_height, img_width, num_channels = image_ndarray_target_channel.shape

# Calculate step size for cropping (with overlap)
step_height = patch_height - overlap_height
step_width = patch_width - overlap_width

print(f"Image dimensions: {img_height}x{img_width}")
print(f"Patch dimensions: {patch_height}x{patch_width}")
print(f"Overlap: {overlap_height}x{overlap_width}")
print(f"Step size: {step_height}x{step_width}")
# Out:
# Image dimensions: 50400x28800
# Patch dimensions: 1440x1920
# Overlap: 144x192
# Step size: 1296x1728

# %%
# Extend the image to ensure full coverage
extended_image = extend_image(image_ndarray_target_channel, patch_height, patch_width, step_height, step_width)

# Crop the extended image into patches
all_patches_ndarray = crop_image_into_patches(extended_image, patch_height, patch_width, step_height, step_width)

# Print the results
print(f"Number of patches: {len(all_patches_ndarray)}")
print(f"Patch array shape: {all_patches_ndarray.shape}")
print(f"Patch shape: {all_patches_ndarray.shape[1:]}")
# Out:
# INFO:root:Original image dimensions: 50400x28800
# INFO:root:Extra height after patches: 1008
# INFO:root:Extra width after patches: 960
# INFO:root:Padding height required: 288
# INFO:root:Padding width required: 768
# INFO:root:New image dimensions after padding: 50688x29568
# Number of patches: 663
# Patch array shape: (663, 1440, 1920, 2)
# Patch shape: (1440, 1920, 2)

# %%
file_name = f"{output_dir}/patches_{nuclear_chanell_name}_{wholecell_chanell_name}_ndarray.npy"
np.save(file_name, all_patches_ndarray)

# %%
# Iterate over axis 0 of (663, 1440, 1920, 2)
# Pass each patch in shape of (1, H, W, C) to visualize_and_save_patch
patch_vis_dir = f"{output_dir}/patch_visualizations"
for i in range(all_patches_ndarray.shape[0]):
    patch = all_patches_ndarray[i:i+1]
    visualize_and_save_patch(patch, i, patch_vis_dir)
# Out:
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_0.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_1.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_2.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_3.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_4.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_5.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_6.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_7.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_8.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_9.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_10.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_11.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_12.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_13.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_14.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_15.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_16.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_17.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_18.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_19.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_20.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_21.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_22.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_23.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_24.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_25.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_26.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_27.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_28.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_29.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_30.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_31.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_32.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_33.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_34.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_35.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_36.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_37.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_38.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_39.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_40.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_41.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_42.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_43.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_44.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_45.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_46.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_47.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_48.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_49.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_50.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_51.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_52.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_53.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_54.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_55.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_56.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_57.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_58.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_59.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_60.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_61.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_62.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_63.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_64.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_65.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_66.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_67.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_68.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_69.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_70.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_71.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_72.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_73.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_74.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_75.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_76.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_77.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_78.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_79.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_80.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_81.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_82.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_83.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_84.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_85.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_86.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_87.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_88.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_89.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_90.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_91.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_92.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_93.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_94.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_95.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_96.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_97.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_98.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_99.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_100.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_101.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_102.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_103.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_104.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_105.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_106.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_107.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_108.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_109.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_110.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_111.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_112.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_113.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_114.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_115.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_116.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_117.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_118.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_119.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_120.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_121.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_122.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_123.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_124.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_125.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_126.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_127.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_128.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_129.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_130.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_131.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_132.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_133.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_134.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_135.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_136.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_137.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_138.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_139.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_140.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_141.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_142.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_143.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_144.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_145.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_146.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_147.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_148.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_149.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_150.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_151.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_152.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_153.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_154.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_155.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_156.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_157.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_158.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_159.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_160.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_161.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_162.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_163.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_164.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_165.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_166.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_167.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_168.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_169.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_170.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_171.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_172.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_173.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_174.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_175.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_176.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_177.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_178.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_179.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_180.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_181.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_182.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_183.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_184.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_185.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_186.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_187.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch
png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_661.png
# Saved patch visualization at: /workspaces/codex-analysis/0-phenocycler-penntmc-pipeline/out/patch_visualizations/patch_662.png

# %%
# Gernerate a metadata pandas dataframe for the patches
patch_metadata = pd.DataFrame(columns=['patch_id', 'height', 'width', 'nuclear_mean', 'nuclear_std', 'nuclear_non_zero_perc','wholecell_mean', 'wholecell_std', 'wholecell_non_zero_perc'])
patch_metadata['patch_id'] = range(len(all_patches_ndarray))
patch_metadata['height'] = patch_height
patch_metadata['width'] = patch_width
patch_metadata['nuclear_mean'] = [np.mean(patch[:, :, 0]) for patch in all_patches_ndarray]
patch_metadata['nuclear_std'] = [np.std(patch[:, :, 0]) for patch in all_patches_ndarray]
patch_metadata['nuclear_non_zero_perc'] = [np.count_nonzero(patch[:, :, 0]) / (patch_height * patch_width) for patch in all_patches_ndarray]
patch_metadata['wholecell_mean'] = [np.mean(patch[ :, :, 1]) for patch in all_patches_ndarray]
patch_metadata['wholecell_std'] = [np.std(patch[ :, :, 1]) for patch in all_patches_ndarray]
patch_metadata['wholecell_non_zero_perc'] = [np.count_nonzero(patch[:, :, 1]) / (patch_height * patch_width) for patch in all_patches_ndarray]

# %%
patch_metadata.loc[0:15]
# Out:
#     patch_id  height  width  nuclear_mean  nuclear_std  nuclear_non_zero_perc  \
# 0          0    1440   1920      0.000000     0.000000               0.000000
# 1          1    1440   1920      0.000000     0.000000               0.000000
# 2          2    1440   1920      0.000000     0.000000               0.000000
# 3          3    1440   1920      0.000000     0.000000               0.000000
# 4          4    1440   1920      0.000000     0.000000               0.000000
# 5          5    1440   1920      0.000000     0.000000               0.000000
# 6          6    1440   1920      1.123402     1.035973               0.884536
# 7          7    1440   1920      4.388422     3.284918               0.988349
# 8          8    1440   1920      6.069073     3.507168               0.998627
# 9          9    1440   1920      5.156181     4.108016               0.997407
# 10        10    1440   1920      3.919785     3.968489               0.988740
# 11        11    1440   1920      2.248434     3.627561               0.983110
# 12        12    1440   1920      0.442232     0.534931               0.427760
# 13        13    1440   1920      0.000000     0.000000               0.000000
# 14        14    1440   1920      0.000000     0.000000               0.000000
# 15        15    1440   1920      0.000000     0.000000               0.000000
#
#     wholecell_mean  wholecell_std  wholecell_non_zero_perc
# 0         0.000000       0.000000                 0.000000
# 1         0.000000       0.000000                 0.000000
# 2         0.000000       0.000000                 0.000000
# 3         0.000000       0.000000                 0.000000
# 4         0.000000       0.000000                 0.000000
# 5         0.003621       0.158817                 0.000557
# 6         0.250013       1.904538                 0.055420
# 7         0.119828       0.775899                 0.061963
# 8         0.411727       2.703638                 0.079941
# 9         1.113294       4.312980                 0.178838
# 10        0.342527       1.623671                 0.093740
# 11        0.630896       3.449906                 0.106846
# 12        0.025408       0.411471                 0.013133
# 13        0.000000       0.000000                 0.000000
# 14        0.000000       0.000000                 0.000000
# 15        0.000000       0.000000                 0.000000

# %%
idx = 6
visualize_patch(all_patches_ndarray[idx:idx+1], idx)
# Out:
# Patch shape: (1, 1440, 1920, 2)
# RGB Patch shape: (1, 1440, 1920, 3)

# %%
idx = 7
visualize_patch(all_patches_ndarray[idx:idx+1], idx)
# Out:
# Patch shape: (1, 1440, 1920, 2)
# RGB Patch shape: (1, 1440, 1920, 3)
